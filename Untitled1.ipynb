# %%
from sklearn.datasets import load_digits
digits=load_digits()

# %%
X=digits.data
y=digits.target
X.shape
# Out:
# (1797, 64)

# %%
from sklearn.linear_model import SGDClassifier;from sklearn.model_selection import cross_val_score

sgdc=SGDClassifier(random_state=10)
np.mean(cross_val_score(sgdc,X,y,scoring='accuracy',cv=3))
# Out:
# 0.912632164718976

# %%
from sklearn.model_selection import cross_val_predict
y_pred=cross_val_predict(sgdc,X,y,cv=3)
y_pred
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
from sklearn.metrics import confusion_matrix;import seaborn as sns;
cf=confusion_matrix(y,y_pred)
sns.heatmap(cf,annot=True,fmt='d')

# %%
from sklearn.model_selection import cross_val_score
y_pred=cross_val_predict(sgdc,X,y,cv=3)
f1_score(y,y_pred,average='macro')
# Out:
# 0.9134462574439709
